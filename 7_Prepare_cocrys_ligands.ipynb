# %%
prot_name = 'erk2'

# %%
DIR_LIGS = F'../ARCHIVOS/CRISTALES/LIGS_{prot_name.upper()}'
dir_inputs = F'{DIR_LIGS}/POCKET_LIGS/'
dir_outputs_sdf = F'{DIR_LIGS}/POCKET_LIGS_PREP_SDF/'
dir_outputs_mol2 = F'{DIR_LIGS}/POCKET_LIGS_PREP_MOL2/'
dir_outputs_pdb = F'{DIR_LIGS}/POCKET_LIGS_PREP_PDB/'

# %%
import os
if not os.path.exists(dir_outputs_pdb):
    os.makedirs(dir_outputs_sdf)
    os.makedirs(dir_outputs_mol2)
    os.makedirs(dir_outputs_pdb)

# %%
# %%bash -s "$dir_inputs" "$dir_outputs_sdf" "$dir_outputs_mol2" "$dir_outputs_pdb"
# for i in `ls ${1}`
# do
#     name=${i%.pdb}
#     babel -ipdb ${1}$i -osdf -O ${2}${name}.sdf  -p 7
#     babel -ipdb ${1}$i -omol2 -O ${3}${name}.mol2 --gen3d -p 7
#     pdb4amber -i ${1}$i -o ${4}${name}.pdb --add-missing-atoms
#     echo $i
# done
# Out:
# 1gol_ATP_LIG.pdb
# 1pme_SB2_LIG.pdb
# 1tvo_FRZ_LIG.pdb
# 1wzy_F29_LIG.pdb
# 2ojg_19A_LIG.pdb
# 2oji_33A_LIG.pdb
# 2ojj_82A_LIG.pdb
# 2y9q_ANP_LIG.pdb
# 2z7l_S91_LIG.pdb
# 3c9w_HMY_LIG.pdb
# 3erk_SB4_LIG.pdb
# 3i5z_Z48_LIG.pdb
# 3i60_E86_LIG.pdb
# 3qyw_6PB_LIG.pdb
# 3qyz_Z8B_LIG.pdb
# 3sa0_NRA_LIG.pdb
# 3tei_ANP_LIG.pdb
# 3w55_1FM_LIG.pdb
# 4erk_OLO_LIG.pdb
# 4fmq_ANP_LIG.pdb
# 4fux_E75_LIG.pdb
# 4fuy_EK2_LIG.pdb
# 4fv0_EK3_LIG.pdb
# 4fv1_EK4_LIG.pdb
# 4fv2_EK5_LIG.pdb
# 4fv3_EK6_LIG.pdb
# 4fv4_EK7_LIG.pdb
# 4fv5_EK9_LIG.pdb
# 4fv6_E57_LIG.pdb
# 4fv7_E94_LIG.pdb
# 4fv8_E63_LIG.pdb
# 4fv9_E71_LIG.pdb
# 4g6n_EK0_LIG.pdb
# 4g6o_E28_LIG.pdb
# 4gsb_PGE_LIG.pdb
# 4gt3_ATP_LIG.pdb
# 4gva_ADP_LIG.pdb
# 4h3p_ANP_LIG.pdb
# 4h3q_ANP_LIG.pdb
# 4i5h_G17_LIG.pdb
# 4iz5_ADP_LIG.pdb
# 4n0s_DHC_LIG.pdb
# 4n4s_2H1_LIG.pdb
# 4nif_ANP_LIG.pdb
# 4o6e_2SH_LIG.pdb
# 4qp1_EMU_LIG.pdb
# 4qp2_36R_LIG.pdb
# 4qp3_36Q_LIG.pdb
# 4qp4_36O_LIG.pdb
# 4qp6_36N_LIG.pdb
# 4qp7_363_LIG.pdb
# 4qp8_362_LIG.pdb
# 4qp9_35X_LIG.pdb
# 4qpa_35W_LIG.pdb
# 4qta_38Z_LIG.pdb
# 4qte_390_LIG.pdb
# 4qyy_3G7_LIG.pdb
# 4s32_ANP_LIG.pdb
# 4s33_ANP_LIG.pdb
# 4s34_ANP_LIG.pdb
# 4xj0_41B_LIG.pdb
# 4xne_TT4_LIG.pdb
# 4xoy_CME_LIG.pdb
# 4xoz_620_LIG.pdb
audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/3i5z_Z48_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# Z48
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# bash: línea 1: 29618 Violación de segmento  (`core' generado) babel -ipdb ${1}$i -omol2 -O ${3}${name}.mol2 --gen3d -p 7
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/3i60_E86_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# E86
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 173 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/3qyw_6PB_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 6PB
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 43 audit log messages
# 1 molecule converted
# 187 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/3qyz_Z8B_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# Z8B
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 183 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/3sa0_NRA_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# NRA
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 59 audit log messages
# 1 molecule converted
# 287 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/3tei_ANP_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# ANP
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 43 audit log messages
# 1 molecule converted
# 176 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/3w55_1FM_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 1FM
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 200 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4erk_OLO_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# OLO
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 59 audit log messages
# 1 molecule converted
# 287 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4fmq_ANP_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# ANP
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 37 audit log messages
# 1 molecule converted
# 309 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4fux_E75_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# E75
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 37 audit log messages
# 1 molecule converted
# 283 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4fuy_EK2_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# EK2
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 37 audit log messages
# 1 molecule converted
# 281 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4fv0_EK3_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# EK3
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 37 audit log messages
# 1 molecule converted
# 330 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4fv1_EK4_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# EK4
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 37 audit log messages
# 1 molecule converted
# 307 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4fv2_EK5_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# EK5
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 43 audit log messages
# 1 molecule converted
# 313 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4fv3_EK6_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# EK6
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 37 audit log messages
# 1 molecule converted
# 279 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4fv4_EK7_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# EK7
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 37 audit log messages
# 1 molecule converted
# 321 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4fv5_EK9_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# EK9
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 37 audit log messages
# 1 molecule converted
# 325 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4fv6_E57_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# E57
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 44 audit log messages
# 1 molecule converted
# 397 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4fv7_E94_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# E94
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 37 audit log messages
# 1 molecule converted
# 347 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4fv8_E63_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# E63
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 37 audit log messages
# 1 molecule converted
# 289 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4fv9_E71_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# E71
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 37 audit log messages
# 1 molecule converted
# 197 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4g6n_EK0_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# EK0
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 44 audit log messages
# 1 molecule converted
# 347 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4g6o_E28_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# E28
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 32 audit log messages
# 1 molecule converted
# 92 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4gsb_PGE_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# PGE
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 51 audit log messages
# 1 molecule converted
# 279 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4gt3_ATP_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# ATP
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 51 audit log messages
# 1 molecule converted
# 255 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4gva_ADP_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# ADP
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 59 audit log messages
# 1 molecule converted
# 287 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4h3p_ANP_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# ANP
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 59 audit log messages
# 1 molecule converted
# 287 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4h3q_ANP_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# ANP
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 288 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4i5h_G17_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# G17
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 51 audit log messages
# 1 molecule converted
# 255 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4iz5_ADP_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# ADP
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 44 audit log messages
# 1 molecule converted
# 185 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4n0s_DHC_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# DHC
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 263 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4n4s_2H1_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 2H1
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 59 audit log messages
# 1 molecule converted
# 287 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4nif_ANP_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# B
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# ANP
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 252 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4o6e_2SH_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 2SH
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 43 audit log messages
# 1 molecule converted
# 181 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4qp1_EMU_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# EMU
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 129 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4qp2_36R_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 36R
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 43 audit log messages
# 1 molecule converted
# 197 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4qp3_36Q_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 36Q
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 42 audit log messages
# 1 molecule converted
# 142 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4qp4_36O_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 36O
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 118 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4qp6_36N_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 36N
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 155 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4qp7_363_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 363
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 195 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4qp8_362_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 362
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 209 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4qp9_35X_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 35X
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 43 audit log messages
# 1 molecule converted
# 249 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4qpa_35W_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 35W
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 43 audit log messages
# 1 molecule converted
# 361 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4qta_38Z_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 38Z
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# bash: línea 1: 30067 Violación de segmento  (`core' generado) babel -ipdb ${1}$i -omol2 -O ${3}${name}.mol2 --gen3d -p 7
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4qte_390_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 390
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 43 audit log messages
# 1 molecule converted
# 281 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4qyy_3G7_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 3G7
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 43 audit log messages
# 1 molecule converted
# 223 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4s32_ANP_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# ANP
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 51 audit log messages
# 1 molecule converted
# 251 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4s33_ANP_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# ANP
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 59 audit log messages
# 1 molecule converted
# 285 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4s34_ANP_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# ANP
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 272 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4xj0_41B_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 41B
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 143 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4xne_TT4_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# TT4
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 39 audit log messages
# 1 molecule converted
# 105 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4xoy_CME_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# CME
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 195 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4xoz_620_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 620
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 39 audit log messages
# 1 molecule converted
# 104 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4xp0_CME_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# CME
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 143 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4xp2_TT4_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# TT4
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 42 audit log messages
# 1 molecule converted
# 118 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4xp3_DX4_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# DX4
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 195 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4xrj_620_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 620
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 133 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4xrl_42A_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 42A
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 40 audit log messages
# 1 molecule converted
# 128 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4zxt_CME_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# CME
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 34 audit log messages
# bash: línea 1: 30225 Violación de segmento  (`core' generado) babel -ipdb ${1}$i -omol2 -O ${3}${name}.mol2 --gen3d -p 7
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4zzm_CQ6_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# CQ6
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 223 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4zzn_CQ8_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# CQ8
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 230 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/4zzo_CQ3_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# CQ3
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 169 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/5ax3_5ID_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 5ID
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 253 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/5bue_4V8_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 4V8
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 205 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/5bui_4V9_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 4V9
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 211 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/5buj_4VB_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 4VB
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 285 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/5bvd_4VF_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 4VF
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# bash: línea 1: 30302 Violación de segmento  (`core' generado) babel -ipdb ${1}$i -omol2 -O ${3}${name}.mol2 --gen3d -p 7
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/5bve_4VG_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 4VG
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 285 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/5bvf_4VJ_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 4VJ
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 44 audit log messages
# 1 molecule converted
# 505 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/5hd4_38Z_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 38Z
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 44 audit log messages
# 1 molecule converted
# 485 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/5hd7_38Z_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 38Z
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 258 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/5k4i_6QB_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 6QB
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 37 audit log messages
# 1 molecule converted
# 299 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/5ke0_6S9_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 6S9
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 37 audit log messages
# 1 molecule converted
# 517 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/5lcj_6TS_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 6TS
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 37 audit log messages
# ...
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6fn5_DVZ_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# DVZ
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 43 audit log messages
# 1 molecule converted
# 247 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6fq7_E2K_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# E2K
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 241 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6fr1_E3K_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# E3K
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 189 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6frp_ZAS_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# ZAS
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 249 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6fxv_E9W_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# E9W
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 43 audit log messages
# bash: línea 1: 30726 Violación de segmento  (`core' generado) babel -ipdb ${1}$i -omol2 -O ${3}${name}.mol2 --gen3d -p 7
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6g54_6H3_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 6H3
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 37 audit log messages
# 1 molecule converted
# 147 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6g8x_EQT_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# EQT
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 37 audit log messages
# 1 molecule converted
# 179 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6g91_EQW_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# EQW
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 37 audit log messages
# 1 molecule converted
# 191 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6g92_ERZ_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# ERZ
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 37 audit log messages
# 1 molecule converted
# 315 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6g93_EU2_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# EU2
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 37 audit log messages
# 1 molecule converted
# 329 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6g97_EQZ_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# EQZ
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 44 audit log messages
# 1 molecule converted
# 403 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6g9a_ESQ_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# ESQ
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 37 audit log messages
# 1 molecule converted
# 367 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6g9d_ER8_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# ER8
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 37 audit log messages
# 1 molecule converted
# 387 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6g9h_ERW_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# ERW
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 37 audit log messages
# 1 molecule converted
# 419 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6g9j_ERK_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# ERK
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 37 audit log messages
# 1 molecule converted
# 423 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6g9k_ESK_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# ESK
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 37 audit log messages
# 1 molecule converted
# 427 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6g9m_ESW_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# ESW
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 37 audit log messages
# 1 molecule converted
# 457 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6g9n_ESN_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# ESN
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 44 audit log messages
# 1 molecule converted
# 495 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6gdm_F3Z_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# F3Z
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 37 audit log messages
# 1 molecule converted
# 325 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6gdq_EVK_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# EVK
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 37 audit log messages
# 1 molecule converted
# 431 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6ge0_EVQ_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# EVQ
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 37 audit log messages
# 1 molecule converted
# 547 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6gjb_F0H_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# F0H
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 44 audit log messages
# 1 molecule converted
# 779 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6gjd_F0E_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# F0E
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 59 audit log messages
# 1 molecule converted
# 285 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6opg_ANP_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# ANP
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 249 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6oph_6QB_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 6QB
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 43 audit log messages
# 1 molecule converted
# 395 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6opi_N0V_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# N0V
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 35 audit log messages
# 1 molecule converted
# 279 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6opk_390_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# 390
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 36 audit log messages
# 1 molecule converted
# 102 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6qal_HV2_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# HV2
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 44 audit log messages
# 1 molecule converted
# 135 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6qaq_HVQ_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# HVQ
#
# ---------- Mising heavy atom(s)
#
# None
# 1 molecule converted
# 44 audit log messages
# 1 molecule converted
# 231 audit log messages
#
# ==================================================
# Summary of pdb4amber for: ../ARCHIVOS/CRISTALES/LIGS_ERK2/POCKET_LIGS/6qaw_HVE_LIG.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# A
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
# HVE
#
# ---------- Mising heavy atom(s)
#
# None

# %%
impor nglview as nv
